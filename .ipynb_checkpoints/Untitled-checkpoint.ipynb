# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt
import pandas as pd

MATCH_ID = 901
START_MS = 4032000   # possible sequence [58400, 67040], [67840, 72840], [75000, 82400], [91680, 106880], [108360, 118440], [120760,136040]
END_MS = 4040000
FPS = 25
PER_FRAME = 1000/FPS  # 40ms per frame
MIN_DETECTOR_SCORE = 0.25
COLOR_HIST_NPZ = "/Users/geraldtan/Desktop/NUS Modules/Dissertation/Ground Truth Player Tracking Data/M-%d-GroundTruth/soccer-player-npz/M-%d-player-npz.npz"%(MATCH_ID, MATCH_ID)
OUT_CSV = './csv/player_detection_colorhist/m-%03d-player-dt%02d-team-%d-%d.csv'%(MATCH_ID, MIN_DETECTOR_SCORE*100, START_MS, END_MS)
VIDEO = '/Users/geraldtan/Desktop/NUS Modules/Dissertation/Deep Sort/detectron2-deepsort-pytorch/original_vids/m-%03d.mp4'%MATCH_ID

# %%
df = pd.read_csv(OUT_CSV)

# %%
df.head()
# Out:
#    time_ms      x1     y1      x2     y2    score     t1_cs   t1gk_cs  \
# 0  4032000   568.4  483.4   614.2  595.9  0.99884  1.920127  1.139605
# 1  4032000    87.5  319.0   130.5  419.0  0.99785  1.530612  1.116014
# 2  4032000  1054.9  284.7  1085.3  363.9  0.99742  1.416022  0.909154
# 3  4032000   420.3  325.8   450.4  421.0  0.99704  3.874456  1.291072
# 4  4032000   966.7  309.6   993.1  395.7  0.99532  2.048001  0.864584
#
#       t2_cs   t2gk_cs    ref_cs
# 0  4.979195  0.462018  1.255112
# 1  4.600633  0.641927  1.218628
# 2  4.851333  0.517082  1.394537
# 3  3.059530  0.498989  1.133481
# 4  2.967061  0.467424  1.277055

# %%
cap = cv2.VideoCapture(VIDEO)
t = START_MS
cap.set(0, t)
while t == START_MS:
    ret, frame = cap.read()
#     cv2_imshow(frame)
    t+= PER_FRAME
    match_image = frame

# %%
df_first_frame = df[df["time_ms"] == 4032000]
df_first_frame.head()
# Out:
#    time_ms      x1     y1      x2     y2    score     t1_cs   t1gk_cs  \
# 0  4032000   568.4  483.4   614.2  595.9  0.99884  1.920127  1.139605
# 1  4032000    87.5  319.0   130.5  419.0  0.99785  1.530612  1.116014
# 2  4032000  1054.9  284.7  1085.3  363.9  0.99742  1.416022  0.909154
# 3  4032000   420.3  325.8   450.4  421.0  0.99704  3.874456  1.291072
# 4  4032000   966.7  309.6   993.1  395.7  0.99532  2.048001  0.864584
#
#       t2_cs   t2gk_cs    ref_cs
# 0  4.979195  0.462018  1.255112
# 1  4.600633  0.641927  1.218628
# 2  4.851333  0.517082  1.394537
# 3  3.059530  0.498989  1.133481
# 4  2.967061  0.467424  1.277055

# %%
for ID, row in df_first_frame.iterrows():
    start_point = (int(row[1]), int(row[2]))
    end_point = (int(row[3]), int(row[4]))
    colors = [(255,0,0), (0,255,0), (0,0,255), (0,255,255)]
    thickness = 2
    cv2.rectangle(match_image, start_point, end_point, color, thickness)

cv2_imshow(match_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F9B7BBFFA90>

# %%
type(df_first_frame)
# Out:
# pandas.core.frame.DataFrame

# %%
for ID, row in df_first_frame.iterrows():
    print(row)
# Out:
# time_ms    4.032000e+06
# x1         5.684000e+02
# y1         4.834000e+02
# x2         6.142000e+02
# y2         5.959000e+02
# score      9.988400e-01
# t1_cs      1.920127e+00
# t1gk_cs    1.139605e+00
# t2_cs      4.979195e+00
# t2gk_cs    4.620180e-01
# ref_cs     1.255112e+00
# Name: 0, dtype: float64
# time_ms    4.032000e+06
# x1         8.750000e+01
# y1         3.190000e+02
# x2         1.305000e+02
# y2         4.190000e+02
# score      9.978500e-01
# t1_cs      1.530612e+00
# t1gk_cs    1.116014e+00
# t2_cs      4.600633e+00
# t2gk_cs    6.419270e-01
# ref_cs     1.218628e+00
# Name: 1, dtype: float64
# time_ms    4.032000e+06
# x1         1.054900e+03
# y1         2.847000e+02
# x2         1.085300e+03
# y2         3.639000e+02
# score      9.974200e-01
# t1_cs      1.416022e+00
# t1gk_cs    9.091540e-01
# t2_cs      4.851333e+00
# t2gk_cs    5.170820e-01
# ref_cs     1.394537e+00
# Name: 2, dtype: float64
# time_ms    4.032000e+06
# x1         4.203000e+02
# y1         3.258000e+02
# x2         4.504000e+02
# y2         4.210000e+02
# score      9.970400e-01
# t1_cs      3.874456e+00
# t1gk_cs    1.291072e+00
# t2_cs      3.059530e+00
# t2gk_cs    4.989890e-01
# ref_cs     1.133481e+00
# Name: 3, dtype: float64
# time_ms    4.032000e+06
# x1         9.667000e+02
# y1         3.096000e+02
# x2         9.931000e+02
# y2         3.957000e+02
# score      9.953200e-01
# t1_cs      2.048001e+00
# t1gk_cs    8.645840e-01
# t2_cs      2.967061e+00
# t2gk_cs    4.674240e-01
# ref_cs     1.277055e+00
# Name: 4, dtype: float64
# time_ms    4.032000e+06
# x1         7.457000e+02
# y1         2.016000e+02
# x2         7.691000e+02
# y2         2.731000e+02
# score      9.929800e-01
# t1_cs      2.460202e+00
# t1gk_cs    9.273330e-01
# t2_cs      1.754720e+00
# t2gk_cs    3.379790e-01
# ref_cs     6.787720e-01
# Name: 5, dtype: float64
# time_ms    4.032000e+06
# x1         5.671000e+02
# y1         2.466000e+02
# x2         5.932000e+02
# y2         3.222000e+02
# score      9.904800e-01
# t1_cs      9.832230e-01
# t1gk_cs    7.393740e-01
# t2_cs      3.125244e+00
# t2gk_cs    3.762380e-01
# ref_cs     5.380300e-01
# Name: 6, dtype: float64
# time_ms    4.032000e+06
# x1         2.454000e+02
# y1         2.365000e+02
# x2         2.701000e+02
# y2         3.128000e+02
# score      9.885800e-01
# t1_cs      4.031470e-01
# t1gk_cs    1.109964e+00
# t2_cs      9.288360e-01
# t2gk_cs    4.186500e-01
# ref_cs     4.363570e-01
# Name: 7, dtype: float64
# time_ms    4.032000e+06
# x1         1.247000e+02
# y1         1.766000e+02
# x2         1.579000e+02
# y2         2.413000e+02
# score      9.700000e-01
# t1_cs      1.014210e-01
# t1gk_cs    6.220210e-01
# t2_cs      1.803630e-01
# t2gk_cs    8.516100e-02
# ref_cs     4.037900e-02
# Name: 8, dtype: float64
# time_ms    4.032000e+06
# x1         1.230500e+03
# y1         3.064000e+02
# x2         1.264300e+03
# y2         3.893000e+02
# score      9.664800e-01
# t1_cs      9.185430e-01
# t1gk_cs    9.844020e-01
# t2_cs      1.254251e+00
# t2gk_cs    7.627120e-01
# ref_cs     4.102510e+00
# Name: 9, dtype: float64
# time_ms    4.032000e+06
# x1         9.275000e+02
# y1         1.928000e+02
# x2         9.583000e+02
# y2         2.556000e+02
# score      9.574600e-01
# t1_cs      3.563560e-01
# t1gk_cs    3.819870e-01
# t2_cs      9.743560e-01
# t2gk_cs    1.046490e-01
# ref_cs     1.000420e-01
# Name: 10, dtype: float64
# time_ms    4.032000e+06
# x1         2.112000e+02
# y1         1.445000e+02
# x2         2.295000e+02
# y2         1.866000e+02
# score      9.087900e-01
# t1_cs      4.440390e-01
# t1gk_cs    2.492130e-01
# t2_cs      7.931090e-01
# t2gk_cs    1.768400e-02
# ref_cs     3.610910e-01
# Name: 11, dtype: float64
# time_ms    4.032000e+06
# x1         6.469000e+02
# y1         1.332000e+02
# x2         6.754000e+02
# y2         1.862000e+02
# score      8.704800e-01
# t1_cs      2.788210e-01
# t1gk_cs    2.957360e-01
# t2_cs      6.255550e-01
# t2gk_cs    8.162300e-02
# ref_cs     1.123780e-01
# Name: 12, dtype: float64
# time_ms    4.032000e+06
# x1         3.173000e+02
# y1         1.462000e+02
# x2         3.372000e+02
# y2         1.872000e+02
# score      8.286400e-01
# t1_cs      3.190660e-01
# t1gk_cs    3.122910e-01
# t2_cs      4.700950e-01
# t2gk_cs    1.408900e-01
# ref_cs     3.217390e-01
# Name: 13, dtype: float64
# time_ms    4.032000e+06
# x1         8.187000e+02
# y1         1.288000e+02
# x2         8.405000e+02
# y2         1.838000e+02
# score      8.236300e-01
# t1_cs      1.918600e-02
# t1gk_cs    3.455200e-01
# t2_cs      2.090690e-01
# t2gk_cs    7.242600e-02
# ref_cs     1.196200e-02
# Name: 14, dtype: float64
# time_ms    4.032000e+06
# x1         6.652000e+02
# y1         1.892000e+02
# x2         6.835000e+02
# y2         2.443000e+02
# score      8.022200e-01
# t1_cs      1.541100e-02
# t1gk_cs    1.373560e-01
# t2_cs      8.007600e-02
# t2gk_cs    1.078900e-02
# ref_cs     4.315600e-02
# Name: 15, dtype: float64
# time_ms    4.032000e+06
# x1         9.370000e+01
# y1         1.424000e+02
# x2         1.142000e+02
# y2         1.873000e+02
# score      6.437600e-01
# t1_cs      2.372970e-01
# t1gk_cs    5.256800e-02
# t2_cs      3.549240e-01
# t2gk_cs    4.337400e-02
# ref_cs     3.625980e-01
# Name: 16, dtype: float64
# time_ms    4.032000e+06
# x1         1.999000e+02
# y1         2.026000e+02
# x2         2.208000e+02
# y2         2.219000e+02
# score      5.612300e-01
# t1_cs      5.738110e-01
# t1gk_cs    7.608000e-03
# t2_cs      4.970110e-01
# t2gk_cs    0.000000e+00
# ref_cs     0.000000e+00
# Name: 17, dtype: float64
# time_ms    4.032000e+06
# x1         9.913000e+02
# y1         1.373000e+02
# x2         1.012600e+03
# y2         1.815000e+02
# score      5.445200e-01
# t1_cs      5.878400e-02
# t1gk_cs    1.341910e-01
# t2_cs      2.587020e-01
# t2gk_cs    0.000000e+00
# ref_cs     5.981000e-03
# Name: 18, dtype: float64
# time_ms    4.032000e+06
# x1         1.350000e+01
# y1         1.265000e+02
# x2         4.570000e+01
# y2         1.851000e+02
# score      4.468000e-01
# t1_cs      1.446604e+00
# t1gk_cs    0.000000e+00
# t2_cs      8.460340e-01
# t2gk_cs    0.000000e+00
# ref_cs     0.000000e+00
# Name: 19, dtype: float64
# time_ms    4.032000e+06
# x1         1.166300e+03
# y1         1.204000e+02
# x2         1.185500e+03
# y2         1.411000e+02
# score      4.081800e-01
# t1_cs      0.000000e+00
# t1gk_cs    0.000000e+00
# t2_cs      3.049800e-02
# t2gk_cs    0.000000e+00
# ref_cs     0.000000e+00
# Name: 20, dtype: float64
# time_ms    4.032000e+06
# x1         1.270000e+03
# y1         2.420000e+02
# x2         1.280000e+03
# y2         2.893000e+02
# score      3.834300e-01
# t1_cs      9.308730e-01
# t1gk_cs    1.662310e-01
# t2_cs      9.931620e-01
# t2gk_cs    7.825900e-02
# ref_cs     6.516930e-01
# Name: 21, dtype: float64
# time_ms    4.032000e+06
# x1         1.132800e+03
# y1         1.196000e+02
# x2         1.155900e+03
# y2         1.777000e+02
# score      3.667300e-01
# t1_cs      5.250000e-03
# t1gk_cs    1.475700e-02
# t2_cs      4.962500e-02
# t2gk_cs    1.973000e-02
# ref_cs     0.000000e+00
# Name: 22, dtype: float64
# time_ms    4.032000e+06
# x1         1.187800e+03
# y1         1.301000e+02
# x2         1.215400e+03
# y2         1.799000e+02
# score      3.322700e-01
# t1_cs      4.629400e-02
# t1gk_cs    4.005790e-01
# t2_cs      2.251520e-01
# t2gk_cs    9.110100e-02
# ref_cs     2.108800e-02
# Name: 23, dtype: float64
# time_ms    4.032000e+06
# x1         6.461000e+02
# y1         9.840000e+01
# x2         6.919000e+02
# y2         1.445000e+02
# score      2.801200e-01
# t1_cs      2.460600e-01
# t1gk_cs    0.000000e+00
# t2_cs      1.891050e-01
# t2gk_cs    0.000000e+00
# ref_cs     0.000000e+00
# Name: 24, dtype: float64
# time_ms    4.032000e+06
# x1         4.847000e+02
# y1         1.428000e+02
# x2         5.030000e+02
# y2         1.863000e+02
# score      2.707100e-01
# t1_cs      1.710800e-01
# t1gk_cs    2.036130e-01
# t2_cs      2.376330e-01
# t2gk_cs    4.331400e-02
# ref_cs     4.946700e-02
# Name: 25, dtype: float64
